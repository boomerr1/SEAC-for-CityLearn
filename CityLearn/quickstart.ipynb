# %% [markdown]
# <a href="https://colab.research.google.com/github/intelligent-environments-lab/CityLearn/blob/master/examples/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QuickStart
#
# Install the latest CityLearn version from PyPi with the :code:`pip` command:

# %%
from citylearn.agents.marlisa import MARLISA
from citylearn.citylearn import CityLearnEnv, EvaluationCondition

dataset_name = 'citylearn_challenge_2022_phase_1'
env = CityLearnEnv(dataset_name, central_agent=False, simulation_end_time_step=1000)
model = MARLISA(env)
model.learn(episodes=1, deterministic_finish=False)

# print cost functions at the end of episode
kpis = model.env.evaluate(baseline_condition=EvaluationCondition.WITHOUT_STORAGE_BUT_WITH_PARTIAL_LOAD_AND_PV)
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                   Building_1  Building_2  Building_3  \
# cost_function
# annual_peak_average                           NaN         NaN         NaN
# carbon_emissions_total                   1.203640    1.308568    1.258879
# cost_total                               1.190653    1.279513    1.248048
# daily_one_minus_load_factor_average           NaN         NaN         NaN
# daily_peak_average                            NaN         NaN         NaN
# discomfort_delta_average                 0.000000    0.000000    0.000000
# discomfort_delta_maximum                 0.000000    0.000000    0.000000
# discomfort_delta_minimum                 0.000000    0.000000    0.000000
# electricity_consumption_total            1.201969    1.317117    1.265285
# monthly_one_minus_load_factor_average         NaN         NaN         NaN
# ramping_average                               NaN         NaN         NaN
# zero_net_energy                          1.123774    1.164488    1.166342
#
# name                                   Building_4  Building_5  District
# cost_function
# annual_peak_average                           NaN         NaN  1.150089
# carbon_emissions_total                   1.533112    1.422006  1.345241
# cost_total                               1.551473    1.346260  1.323189
# daily_one_minus_load_factor_average           NaN         NaN  1.003019
# daily_peak_average                            NaN         NaN  1.195925
# discomfort_delta_average                 0.000000    0.000000  0.000000
# discomfort_delta_maximum                 0.000000    0.000000  0.000000
# discomfort_delta_minimum                 0.000000    0.000000  0.000000
# electricity_consumption_total            1.517496    1.466137  1.353601
# monthly_one_minus_load_factor_average         NaN         NaN  0.993746
# ramping_average                               NaN         NaN  1.991575
# zero_net_energy                          1.202521    1.201451  1.171715

# %%
model.learn(episodes=5, deterministic_finish=False)

kpis = model.env.evaluate(baseline_condition=EvaluationCondition.WITHOUT_STORAGE_BUT_WITH_PARTIAL_LOAD_AND_PV)
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                   Building_1  Building_2  Building_3  \
# cost_function
# annual_peak_average                           NaN         NaN         NaN
# carbon_emissions_total                   1.015497    0.929255    1.036805
# cost_total                               0.955732    0.872519    1.005924
# daily_one_minus_load_factor_average           NaN         NaN         NaN
# daily_peak_average                            NaN         NaN         NaN
# discomfort_delta_average                 0.000000    0.000000    0.000000
# discomfort_delta_maximum                 0.000000    0.000000    0.000000
# discomfort_delta_minimum                 0.000000    0.000000    0.000000
# electricity_consumption_total            1.019103    0.933523    1.030493
# monthly_one_minus_load_factor_average         NaN         NaN         NaN
# ramping_average                               NaN         NaN         NaN
# zero_net_energy                          1.060796    1.047369    1.052831
#
# name                                   Building_4  Building_5  District
# cost_function
# annual_peak_average                           NaN         NaN  1.090995
# carbon_emissions_total                   1.118417    1.042944  1.028584
# cost_total                               1.094143    0.998596  0.985383
# daily_one_minus_load_factor_average           NaN         NaN  0.970659
# daily_peak_average                            NaN         NaN  0.979552
# discomfort_delta_average                 0.000000    0.000000  0.000000
# discomfort_delta_maximum                 0.000000    0.000000  0.000000
# discomfort_delta_minimum                 0.000000    0.000000  0.000000
# electricity_consumption_total            1.117731    1.040136  1.028197
# monthly_one_minus_load_factor_average         NaN         NaN  0.994238
# ramping_average                               NaN         NaN  1.174641
# zero_net_energy                          1.065333    1.076296  1.060525
